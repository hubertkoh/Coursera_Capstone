# %% [markdown]
# ## This notebook was created for IBM Capstone project - The Battle of Neighbourhoods
#
# ## Objective: Come up with an idea to leverage the Foursquare location data to explore or compare neighborhoods or cities of your choice or to come up with a problem that you can use the Foursquare location data to solve.
#
# ## A description of the problem and a discussion of the background. (15 marks)
# ## A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# ### 1) Introduction
# Problem:
# Which town would be a good place to buy a resale HDB in Singapore?

# %%
# insert an image od singapore skyline here
Image(filename='Singapore_view.jpg')

# %% [markdown]
# Discussion of the background:
# As Millennials in Singapore reach a certain age, they will look to settle down and finding a place to stay will increasingly become a top priority. While most young adults stay with their parents, owning a house is every Singaporean dream. This is why despite exorbitant house pricing, most young adults will actually look to buy instead of renting a house in Singapore. While there are pros and cons to this, the ability to find a good area to buy a house with a long term view is good for capital appreciation and convenience
#
# 2 criteria can be used to assess which town is a good place to buy a house.
# 1. Average psf prices of HDBs
# We would like to determine which town and type of resale flat is most attractive by analyzing the datasets
#
# 2. Attractiveness of the area
# The attractiveness of the place is determined by the type of places around it.
# This may include schools,supermarkets workplaces and on so.

# %% [markdown]
# ### 2) Datasets and Methodology

# %% [markdown]
# We will be tackling this problem from a unsupervised machine learning algorithm (K-means clustering) to segment and cluster different towns of Singapore.

# %% [markdown]
# We will need the following datasets
#
# - Data about Towns and HDB resale prices in Singapore
# - Data about the location information (Latitude and Longitude of Towns in Singapore)
# Finally, we will also use Singapore geographic coordinates data as input data for the Foursquare API, which will be used to provide information on the top venues in each SG neighborhood.
#
# 1) Data about Resale HBD Prices in Singapore :
# Data Source : This dataset is available on the Singapore open data website
#
# This is to help determine which town is more attractive.
#
# https://data.gov.sg/dataset/resale-flat-prices
#
# 2) Location Data around Singapore Towns:
# Data Source: Foursquare
# Retrieve the data using foursquare API
#
# This is to help determine which town is most attractive based on venues near it.
